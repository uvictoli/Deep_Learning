# %% [markdown]
# # ⇒ 결과 정리

# %% [markdown]
# 하이퍼 파라미터 변형 모델 외에 data augmentation 적용/미적용 모델은 **epochs = 40, learning_rate = 0.01, early_stop patiance = 10**으로 설정하였습니다.
# ***
# ### 1. Rock_paper_scissors
#  (1) data augmentation 미적용
# - epoch  : 40
# - train / validation 결과 : ``` loss: 1.4516e-04 - accuracy: 1.0000 - val_loss: 1.8684e-05 - val_accuracy: 1.0000 ```
# - test 결과 : ``` loss: 1.8010e-05 - accuracy: 1.0000 ```
#
# (2) data augmentation 적용
# - epoch : 40
# - train / validation 결과 : ``` loss: 2.4532e-04 - accuracy: 1.0000 - val_loss: 4.5468e-06 - val_accuracy: 1.0000 ```
# - test 결과 : ``` loss: 1.2124e-06 - accuracy: 1.0000 ```
#
# (3) 하이퍼 파라미터 변형
# *keras randomsearch 라이브러리 사용하여 하이퍼파리미터 최적화하려고 했으나 시스템 RAM이 초과해서 코랩이 다운되더라고요🥲 코드는 지우지 않고 남겨두었으니 원하시는 분은 실행해보시면 될 것 같습니다*
#   1. **learning rate → 0.1 / 0.00001**
#     - learning_rate = 0.1
#       - epoch  : 14
#       - train / validation 결과 : ```loss: 0.2179 - accuracy: 0.9211 - val_loss: 1.2068 - val_accuracy: 0.6761 ```
#       - test 결과 : ``` loss: 0.0000e+00 - accuracy: 1.0000 ```
#     - learning_rate = 0.00001
#       - epoch  : 40
#       - train / validation 결과 : ```loss: 1.0687 - accuracy: 0.5180 - val_loss: 1.0655 - val_accuracy: 0.5568 ```
#       - test 결과 : ``` loss: 1.0614 - accuracy: 0.5873 ```
#
#   ⇒ 이미 (1), (2)의 테스트 정확도가 1.0이 나왔고 (3) learning_rate = 0.1일 때 epoch 14번만에 테스트 정확도가 1.0이 나와서 다른 하이퍼파라미터는 굳이 수정하지 않았습니다.
#   <U>(3)번 모델은 데이터 증강 + epoch 40(14번째에 조기종료), learning_rate = 0.1 로 저장하였습니다.</U>
#
# ⇒ <U>**최종결과(Rock_paper_scissors)**</U>
#
# | Model                                 | Test Accuracy | Test Loss   | Prediction Time |
# | ------------------------------------- | ------------- | ----------- | --------------- |
# | Xception_without_data_augmentation    | 1.0           | 0.000018    | 0.874107        |
# | Xception_with_data_augmentation       | 1.0           | 0.000001    | 0.904584        |
# | Xception_change_hp                    | 0.992063      | 0.033273    | 0.909968        |
#
# <br>
#
# ***
# ### 2. Citrus_leaves
#  (1) data augmentation 미적용
# - epoch  : 40 (12번째에 조기종료)
# - train / validation 결과 : ``` loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9024 - val_accuracy: 0.7969 ```
# - test 결과 : ``` loss: 0.6950 - accuracy: 0.7288 ```
#
# (2) data augmentation 적용
# - epoch : 40 (11번째에 조기종료)
# - train / validation 결과 : ``` loss: 0.0773 - accuracy: 0.9688 - val_loss: 2.2019 - val_accuracy: 0.3594 ```
# - test 결과 : ``` loss: 1.5011 - accuracy: 0.3051 ```
#
# (3) 하이퍼 파라미터 변형
#   1. **learning rate → 0.1 / 0.00001**
#     - learning_rate = 0.1
#       - epoch  : 31번째에 조기종료
#       - train / validation 결과 : ```loss: 0.1833 - accuracy: 0.9471 - val_loss: 0.9764 - val_accuracy: 0.8281 ```
#       - test 결과 : ``` loss: 0.5730 - accuracy: 0.8475 ```
#     - learning_rate = 0.00001
#       - epoch  : 40
#       - train / validation 결과 : ```loss: 1.2799 - accuracy: 0.4207 - val_loss: 1.2915 - val_accuracy: 0.4219 ```
#       - test 결과 : ``` loss: 1.2280 - accuracy: 0.5424 ```
#
#   ⇒ learning_rate = 0.1일 때 적은 에폭 수로 더 높은 테스트 정확도가 나왔기 때문에 learning_rate = 0.1로 고정하고 epoch을 늘려 실행해보았습니다.
#
#   2. **epochs = 150**
#     - early_stop 미적용
#       - epoch : 150
#       - train / validation 결과 : ```loss: 0.0396 - accuracy: 0.9952 - val_loss: 1.5451 - val_accuracy: 0.8125```
#       - test 결과 : ``` loss: 0.7210 - accuracy: 0.8475 ```
#
#     - early_stop 적용 (patiance = 40)
#       - epoch : 41번째에 조기종료
#       - train / validation 결과 : ```loss: 0.0086 - accuracy: 0.9976 - val_loss: 1.3604 - val_accuracy: 0.8594```
#       - test 결과 : ``` loss: 0.6381 - accuracy: 0.8136 ```
#
#     - epochs = 100 (early_stop 미적용)
#       - epoch : 100
#       - train / validation 결과 : ```accuracy: 0.9976 - val_loss: 1.2727 - val_accuracy: 0.8438```
#       - test 결과 : ``` loss: 0.6913 - accuracy: 0.8475```
#
#   ⇒ learning_rate = 0.1로 동일할 때, epochs = 100이 epochs = 150과 테스트 정확도는 비슷하지만 손실이 더 적어
#   <U>(3)번 모델은 데이터 증강 + epoch 100, learning_rate = 0.1 로 저장하였습니다.</U>
#
# ⇒ <U>**최종결과(Citrus_leaves)**</U>
#
# | Model                               | Test Accuracy | Test Loss | Prediction Time |
# | ----------------------------------- | ------------- | --------- | --------------- |
# | Xception_without_data_augmentation  | 0.728814      | 0.695039  | 0.965492        |
# | Xception_with_data_augmentation     | 0.305085      | 1.501131  | 0.950491        |
# | Xception_change_hp                  | 0.847458      | 0.691276  | 0.925380        |

# %% [markdown]
# # 0. Initialization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

from functools import partial
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras import optimizers
import tensorflow_datasets as tfds

assert tf.__version__ >= "2.0"

# %%
# 8.22 결과를 그래프로 나타내기 
def show_plot(history, save_name = None):
  acc = history.history["accuracy"]
  val_acc = history.history["val_accuracy"]
  loss = history.history["loss"]
  val_loss = history.history["val_loss"]
  epochs = range(1, len(acc) + 1)

  plt.plot(epochs, acc, "bo", label = "Training accuracy")
  plt.plot(epochs, val_acc, "b", label = "Validation accuracy")
  plt.title("Training and validation accuracy")
  plt.legend()
  if save_name == None: pass
  else: plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/accuracy_{save_name}.png')
  plt.figure()
  
  plt.plot(epochs, loss , "bo", label = "Training loss")
  plt.plot(epochs, val_loss, "b", label = "Validation_loss")
  plt.title("Training and validation loss")
  plt.legend()
  if save_name == None: pass
  else: plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/loss_{save_name}.png')
  plt.show()

# %%
# 8.26 테스트 세트에서 모델 평가하기
def model_test(MODEL_PATH, test_set):
  test_model = keras.models.load_model(MODEL_PATH)
  test_loss, test_acc = test_model.evaluate(test_set)
  print(f"테스트 정확도 : {test_acc*100:.3f}%")
  return test_loss, test_acc

# %% [markdown]
# # 1. Rock_paper_scissors

# %% [markdown]
# #### train / validation / test set 분리

# %%
dataset, info = tfds.load("rock_paper_scissors", as_supervised=True, with_info=True)
class_names = info.features["label"].names # ["rock", "paper", "scissors"]
n_classes = info.features["label"].num_classes # 3
dataset_size = info.splits["train"].num_examples # 2520

test_set_raw, valid_set_raw, train_set_raw = tfds.load("rock_paper_scissors", 
                                                       as_supervised=True, 
                                                       split=["train[:10%]","train[10%:25%]", "train[25%:]"])


def preprocess(image, label):
  resized_image = tf.image.resize(image, [224, 224])
  final_image = keras.applications.xception.preprocess_input(resized_image)
  return final_image, label


batch_size = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(preprocess).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

rsp_results = pd.DataFrame(columns = ['test_acc', 'test_loss', 'pred_time'], index = ['Xception_without_data_augmentation', 'Xception_with_data_augmentation', 'Xception_change_hp'])
# Out:
# Downloading and preparing dataset 219.53 MiB (download: 219.53 MiB, generated: Unknown size, total: 219.53 MiB) to /root/tensorflow_datasets/rock_paper_scissors/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/2520 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incompleteH7XW9E/rock_paper_scissors-train.tfrec…
# Generating test examples...:   0%|          | 0/372 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incompleteH7XW9E/rock_paper_scissors-test.tfreco…
# Dataset rock_paper_scissors downloaded and prepared to /root/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ```label names``` = ['rock', 'paper', 'scissors']
# ```num_classes``` = 3
# ```
# FeaturesDict({
#     'image': Image(shape=(300, 300, 3), dtype=uint8),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=3),
# })
# ```
#
# ```
# info.splits
# >>> {Split('train'): <SplitInfo num_examples=2520, num_shards=2>,
#  Split('test'): <SplitInfo num_examples=372, num_shards=1>}
#  ```

# %% [markdown]
# - **데이터 확인**

# %%
plt.figure(figsize=(10, 10))
index = 0
for image, label in train_set_raw.take(9):
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title("Class: {}".format(class_names[label]))
    plt.axis("off")

plt.show()

# %% [markdown]
# ## (1) Data augmentation 미적용

# %%
base_model= keras.applications.xception.Xception(weights="imagenet", include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(n_classes, activation="softmax")(avg)
model = keras.models.Model(inputs=base_model.input, outputs=output)

# fine-tuning
for layer in base_model.layers:
   layer.trainable = True

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/rsp_Xception_without_data_augmentation.keras"
EPOCHS = 40 

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb,
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

model1_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model1_history, "rsp_without_data_augmentation") # history graph
model1_test_loss, model1_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과

start = time.time()
model.predict(test_set)
end = time.time()
model1_predict_time = end - start # prediction_time

rsp_results.loc["Xception_without_data_augmentation"] = (model1_test_acc, model1_test_loss, model1_predict_time)
# Out:
# Epoch 1/40
# 59/59 [==============================] - 23s 107ms/step - loss: 0.1885 - accuracy: 0.9364 - val_loss: 0.6879 - val_accuracy: 0.7131
# Epoch 2/40
# 59/59 [==============================] - 5s 88ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.3057 - val_accuracy: 0.8892
# Epoch 3/40
# 59/59 [==============================] - 5s 88ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 4/40
# 59/59 [==============================] - 5s 88ms/step - loss: 9.6900e-04 - accuracy: 1.0000 - val_loss: 4.6036e-04 - val_accuracy: 1.0000
# Epoch 5/40
# 59/59 [==============================] - 6s 96ms/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 3.4785e-04 - val_accuracy: 1.0000
# Epoch 6/40
# 59/59 [==============================] - 5s 88ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 1.5653e-04 - val_accuracy: 1.0000
# Epoch 7/40
# 59/59 [==============================] - 5s 91ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.4263e-04 - val_accuracy: 1.0000
# Epoch 8/40
# 59/59 [==============================] - 6s 97ms/step - loss: 6.5785e-04 - accuracy: 1.0000 - val_loss: 1.1311e-04 - val_accuracy: 1.0000
# Epoch 9/40
# 59/59 [==============================] - 5s 91ms/step - loss: 8.3294e-04 - accuracy: 1.0000 - val_loss: 9.8683e-05 - val_accuracy: 1.0000
# Epoch 10/40
# 59/59 [==============================] - 5s 91ms/step - loss: 4.1645e-04 - accuracy: 1.0000 - val_loss: 8.5191e-05 - val_accuracy: 1.0000
# Epoch 11/40
# 59/59 [==============================] - 6s 94ms/step - loss: 4.0639e-04 - accuracy: 1.0000 - val_loss: 7.8497e-05 - val_accuracy: 1.0000
# Epoch 12/40
# 59/59 [==============================] - 5s 92ms/step - loss: 6.1446e-04 - accuracy: 1.0000 - val_loss: 7.1513e-05 - val_accuracy: 1.0000
# Epoch 13/40
# 59/59 [==============================] - 6s 96ms/step - loss: 6.5935e-04 - accuracy: 1.0000 - val_loss: 6.6504e-05 - val_accuracy: 1.0000
# Epoch 14/40
# 59/59 [==============================] - 5s 88ms/step - loss: 4.0805e-04 - accuracy: 1.0000 - val_loss: 6.2214e-05 - val_accuracy: 1.0000
# Epoch 15/40
# 59/59 [==============================] - 5s 92ms/step - loss: 1.6833e-04 - accuracy: 1.0000 - val_loss: 2.2866e-05 - val_accuracy: 1.0000
# Epoch 34/40
# 59/59 [==============================] - 6s 96ms/step - loss: 3.4086e-04 - accuracy: 1.0000 - val_loss: 2.2107e-05 - val_accuracy: 1.0000
# Epoch 35/40
# 59/59 [==============================] - 5s 91ms/step - loss: 1.0792e-04 - accuracy: 1.0000 - val_loss: 2.1584e-05 - val_accuracy: 1.0000
# Epoch 36/40
# 59/59 [==============================] - 5s 88ms/step - loss: 1.6652e-04 - accuracy: 1.0000 - val_loss: 2.1032e-05 - val_accuracy: 1.0000
# Epoch 37/40
# 59/59 [==============================] - 5s 88ms/step - loss: 1.4480e-04 - accuracy: 1.0000 - val_loss: 2.0572e-05 - val_accuracy: 1.0000
# Epoch 38/40
# 59/59 [==============================] - 5s 89ms/step - loss: 2.6043e-04 - accuracy: 1.0000 - val_loss: 1.9133e-05 - val_accuracy: 1.0000
# Epoch 39/40
# 59/59 [==============================] - 5s 89ms/step - loss: 1.7664e-04 - accuracy: 1.0000 - val_loss: 1.8836e-05 - val_accuracy: 1.0000
# Epoch 40/40
# 59/59 [==============================] - 5s 89ms/step - loss: 1.4516e-04 - accuracy: 1.0000 - val_loss: 1.8684e-05 - val_accuracy: 1.0000
# 8/8 [==============================] - 1s 45ms/step - loss: 1.8010e-05 - accuracy: 1.0000
# 테스트 정확도 : 100.000%
# 8/8 [==============================] - 1s 14ms/step

# %% [markdown]
# ## (2) Data augmentation 적용

# %%
def central_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]])
    top_crop = (shape[0] - min_dim) // 4
    bottom_crop = shape[0] - top_crop
    left_crop = (shape[1] - min_dim) // 4
    right_crop = shape[1] - left_crop
    return image[top_crop:bottom_crop, left_crop:right_crop]

def random_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]]) * 90 // 100
    return tf.image.random_crop(image, [min_dim, min_dim, 3])


def preprocess(image, label, randomize=False):
    if randomize:
        cropped_image = random_crop(image)
        cropped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        cropped_image = central_crop(image)
    resized_image = tf.image.resize(cropped_image, [224, 224])
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label


# 데이터 증강을 포함한 전처리 함수 정의
def augment_preprocess(image, label):
    augmented_image = data_augmentation(image)
    resized_image = tf.image.resize(augmented_image, [224, 224])
    normalized_image = resized_image / 255.0
    return normalized_image, label

data_augmentation = keras.Sequential( # data augmentation
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# - **augmentation 결과 확인**

# %%
# augmentation 결과 확인 
batch_size = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(augment_preprocess)).batch(batch_size).prefetch(1)
train_set = train_set_raw.map(augment_preprocess)

plt.figure(figsize=(10, 10))
index = 0
for image, label in train_set.take(9):
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title("Class: {}".format(class_names[label]))

plt.show()

# %%
# 모델 적용을 위해 Input_size 수정한 ver
def preprocess(image, label, randomize=False):
    if randomize:
        cropped_image = random_crop(image)
        cropped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        cropped_image = central_crop(image)
    resized_image = tf.image.resize(cropped_image, [224, 224])
    resized_image = tf.squeeze(resized_image)  # 차원 축소
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label

# 데이터 증강을 포함한 전처리 함수 정의 (모델 적용을 위해 Input_size 수정한 ver)
def augment_preprocess(image, label):
    augmented_image = data_augmentation(image)
    resized_image = tf.image.resize(augmented_image, [224, 224])
    normalized_image = resized_image / 255.0
    return normalized_image, label

data_augmentation = keras.Sequential(
    [
        layers.Conv2D(3, 3, input_shape=(224, 224, 3)),  # 입력 형태 설정
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(preprocess, randomize=True)).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

base_model= keras.applications.xception.Xception(weights="imagenet", include_top=False)
# fine-tuning
for layer in base_model.layers:
   layer.trainable = True

# inputs = keras.Input(shape=(None, None, 3)) 
inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  


model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/rsp_Xception_with_data_augmentation.keras"
EPOCHS = 40

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model2_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model2_history, "rsp_with_data_augmentation") # history graph
model2_test_loss, model2_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과

start = time.time()
model.predict(test_set)
end = time.time()
model2_predict_time = end - start # prediction_time

rsp_results.loc["Xception_with_data_augmentation"] = (model2_test_acc, model2_test_loss, model2_predict_time)
# Out:
# Epoch 1/40
# 59/59 [==============================] - 23s 108ms/step - loss: 0.2288 - accuracy: 0.9047 - val_loss: 0.3330 - val_accuracy: 0.8523
# Epoch 2/40
# 59/59 [==============================] - 5s 92ms/step - loss: 0.0222 - accuracy: 0.9931 - val_loss: 0.2712 - val_accuracy: 0.9205
# Epoch 3/40
# 59/59 [==============================] - 5s 91ms/step - loss: 0.0123 - accuracy: 0.9952 - val_loss: 0.2584 - val_accuracy: 0.9205
ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 1.4041e-05 - val_accuracy: 1.0000
# Epoch 26/40
# 59/59 [==============================] - 5s 77ms/step - loss: 2.1093e-04 - accuracy: 1.0000 - val_loss: 1.1459e-05 - val_accuracy: 1.0000
# Epoch 27/40
# 59/59 [==============================] - 5s 77ms/step - loss: 3.5568e-04 - accuracy: 1.0000 - val_loss: 1.9850e-05 - val_accuracy: 1.0000
# Epoch 28/40
# 59/59 [==============================] - 5s 78ms/step - loss: 1.8384e-04 - accuracy: 1.0000 - val_loss: 1.3301e-05 - val_accuracy: 1.0000
# Epoch 29/40
# 59/59 [==============================] - 5s 77ms/step - loss: 2.8330e-04 - accuracy: 1.0000 - val_loss: 9.9744e-06 - val_accuracy: 1.0000
# Epoch 30/40
# 59/59 [==============================] - 6s 110ms/step - loss: 2.6880e-04 - accuracy: 1.0000 - val_loss: 7.2125e-06 - val_accuracy: 1.0000
# Epoch 31/40
# 59/59 [==============================] - 5s 78ms/step - loss: 6.9543e-05 - accuracy: 1.0000 - val_loss: 8.1351e-06 - val_accuracy: 1.0000
# Epoch 32/40
# 59/59 [==============================] - 5s 78ms/step - loss: 1.4019e-04 - accuracy: 1.0000 - val_loss: 7.7531e-06 - val_accuracy: 1.0000
# Epoch 33/40
# 59/59 [==============================] - 7s 111ms/step - loss: 3.2100e-04 - accuracy: 1.0000 - val_loss: 2.3066e-06 - val_accuracy: 1.0000
# Epoch 34/40
# 59/59 [==============================] - 5s 93ms/step - loss: 1.5183e-04 - accuracy: 1.0000 - val_loss: 1.7861e-06 - val_accuracy: 1.0000
# Epoch 35/40
# 59/59 [==============================] - 5s 80ms/step - loss: 8.6935e-04 - accuracy: 0.9995 - val_loss: 4.0752e-06 - val_accuracy: 1.0000
# Epoch 36/40
# 59/59 [==============================] - 5s 80ms/step - loss: 3.1783e-04 - accuracy: 1.0000 - val_loss: 2.9862e-06 - val_accuracy: 1.0000
# Epoch 37/40
# 59/59 [==============================] - 5s 78ms/step - loss: 9.2353e-05 - accuracy: 1.0000 - val_loss: 2.4454e-06 - val_accuracy: 1.0000
# Epoch 38/40
# 59/59 [==============================] - 5s 78ms/step - loss: 1.0262e-04 - accuracy: 1.0000 - val_loss: 2.0004e-06 - val_accuracy: 1.0000
# Epoch 39/40
# 59/59 [==============================] - 5s 78ms/step - loss: 4.0729e-04 - accuracy: 1.0000 - val_loss: 2.2944e-06 - val_accuracy: 1.0000
# Epoch 40/40
# 59/59 [==============================] - 5s 77ms/step - loss: 2.4532e-04 - accuracy: 1.0000 - val_loss: 4.5468e-06 - val_accuracy: 1.0000
# 8/8 [==============================] - 1s 19ms/step - loss: 1.2124e-06 - accuracy: 1.0000
# 테스트 정확도 : 100.000%
# 8/8 [==============================] - 1s 16ms/step

# %% [markdown]
# ## (3) 1-(2)에서 hyper parameter 변형

# %% [markdown]
# - 기존
#   - epochs = 40
#   - learning_rate = 0.01
#   - batch_size = 32

# %% [markdown]
# #### keras RandomSearch 적용하려고 했으나 시스템 RAM 초과하여 코랩 세션이 다운됨(실행 불가능)

# %%
from sklearn.model_selection import RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
import random
import numpy as np

train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(preprocess, randomize=True)).batch(64).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(64).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(64).prefetch(1)

train_images, train_labels = np.array(list(train_set.as_numpy_iterator())).transpose()
valid_images, valid_labels = np.array(list(valid_set.as_numpy_iterator())).transpose()
test_images, test_labels = np.array(list(test_set.as_numpy_iterator())).transpose()

def create_model(learning_rate, momentum, weight_decay, dropout_value):
    base_model = keras.applications.xception.Xception(weights="imagenet", include_top=False)
    for layer in base_model.layers:
        layer.trainable = True
    inputs = keras.Input(shape=(224, 224, 3))
    x = data_augmentation(inputs)
    x = keras.applications.xception.preprocess_input(x)
    x = base_model(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256)(x)
    x = layers.Dropout(dropout_value)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    optimizer = keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum, nesterov=True, weight_decay=weight_decay)
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])
    return model

model = KerasClassifier(build_fn=create_model)

dropout_values = [random.uniform(0, 1) for n in range(5)]
batch_sizes = [random.randint(32, 64) for n in range(5)]
epochs = [random.choice(range(30, 160, 10)) for n in range(5)]
learning_rate = [round(random.uniform(10 ** -7, 100), 7) for _ in range(5)]

param_grid = {
    "learning_rate": learning_rate,
    "momentum": [0.9, 0.95, 0.99],
    "weight_decay": [0.001, 0.01, 0.1],
    "dropout_value" : dropout_values
}

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/rsp_Xception_change_hp.keras"
early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3 = RandomizedSearchCV(model, param_distributions=param_grid, n_iter = 5, cv=3)
model3_history = model3.fit(train_images,
                  train_labels,
                  validation_data=(valid_images, valid_labels),
                  steps_per_epoch=int(0.75 * dataset_size / batch_size),
                  validation_steps=int(0.15 * dataset_size / batch_size),
                  callbacks=callbacks)

show_plot(model3_history, "rsp_change_hp") # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과

start = time.time()
model.predict(test_set)
end = time.time()
model3_predict_time = end - start # prediction_time

rsp_results.loc["Xception_change_hp"] = (model3_test_acc, model3_test_loss, model3_predict_time) 

print("Best Parameters: ", model3.best_params_)
print("Best Score: ", model3.best_score_)

# %%
import pandas as pd

rs = pd.DataFrame(model3.cv_results_).sort_values(by='rank_test_score').head()
rs.T

# %% [markdown]
# #### 1. learning rate 영향

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 40
lr = 0.1

base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False
 
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate= lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/40
# 59/59 [==============================] - 9s 83ms/step - loss: 0.0238 - accuracy: 0.9899 - val_loss: 3.6237e-08 - val_accuracy: 1.0000
# Epoch 2/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 1.6797e-07 - val_accuracy: 1.0000
# Epoch 3/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.0229 - accuracy: 0.9963 - val_loss: 0.0139 - val_accuracy: 0.9972
# Epoch 4/40
# 59/59 [==============================] - 4s 68ms/step - loss: 0.0364 - accuracy: 0.9915 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/40
# 59/59 [==============================] - 4s 63ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 6/40
# 59/59 [==============================] - 4s 64ms/step - loss: 3.9760 - accuracy: 0.8014 - val_loss: 41.3176 - val_accuracy: 0.4432
# Epoch 7/40
# 59/59 [==============================] - 4s 65ms/step - loss: 1.2607 - accuracy: 0.5519 - val_loss: 3.0897 - val_accuracy: 0.6023
# Epoch 8/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.6065 - accuracy: 0.7357 - val_loss: 3.4996 - val_accuracy: 0.5739
# Epoch 9/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.4514 - accuracy: 0.8199 - val_loss: 18.2893 - val_accuracy: 0.3807
# Epoch 10/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.4058 - accuracy: 0.8464 - val_loss: 1.5091 - val_accuracy: 0.6591
# Epoch 11/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.3246 - accuracy: 0.8808 - val_loss: 1.0619 - val_accuracy: 0.7102
# Epoch 12/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.2941 - accuracy: 0.8893 - val_loss: 2.5239 - val_accuracy: 0.5398
# Epoch 13/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.2799 - accuracy: 0.8999 - val_loss: 0.7619 - val_accuracy: 0.7188
# Epoch 14/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.2179 - accuracy: 0.9211 - val_loss: 1.2068 - val_accuracy: 0.6761
# 8/8 [==============================] - 1s 19ms/step - loss: 0.0000e+00 - accuracy: 1.0000
# 테스트 정확도 : 100.000%

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 40
lr = 1e-5

base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False
 
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate= lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/40
# 59/59 [==============================] - 9s 83ms/step - loss: 1.1124 - accuracy: 0.2532 - val_loss: 1.1172 - val_accuracy: 0.3011
# Epoch 2/40
# 59/59 [==============================] - 4s 68ms/step - loss: 1.1116 - accuracy: 0.2648 - val_loss: 1.1125 - val_accuracy: 0.2188
# Epoch 3/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1087 - accuracy: 0.2834 - val_loss: 1.1102 - val_accuracy: 0.2472
# Epoch 4/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1089 - accuracy: 0.2839 - val_loss: 1.1086 - val_accuracy: 0.2670
# Epoch 5/40
# 59/59 [==============================] - 4s 71ms/step - loss: 1.1054 - accuracy: 0.2908 - val_loss: 1.1071 - val_accuracy: 0.2955
# Epoch 6/40
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1058 - accuracy: 0.2865 - val_loss: 1.1058 - val_accuracy: 0.3210
# Epoch 7/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1048 - accuracy: 0.2940 - val_loss: 1.1045 - val_accuracy: 0.3438
# Epoch 8/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1031 - accuracy: 0.3083 - val_loss: 1.1031 - val_accuracy: 0.3494
# Epoch 9/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1031 - accuracy: 0.3120 - val_loss: 1.1019 - val_accuracy: 0.3665
# Epoch 10/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.1013 - accuracy: 0.3136 - val_loss: 1.1007 - val_accuracy: 0.3864
# Epoch 11/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0995 - accuracy: 0.3353 - val_loss: 1.0996 - val_accuracy: 0.4006
# Epoch 12/40
# 59/59 [==============================] - 4s 70ms/step - loss: 1.0986 - accuracy: 0.3353 - val_loss: 1.0984 - val_accuracy: 0.4233
# Epoch 13/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0970 - accuracy: 0.3416 - val_loss: 1.0971 - val_accuracy: 0.4290
# Epoch 14/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0973 - accuracy: 0.3279 - val_loss: 1.0958 - val_accuracy: 0.4432
# Epoch 15/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0972 - accuracy: 0.3469 - val_loss: 1.0947 - val_accuracy: 0.4545
# Epoch 16/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0922 - accuracy: 0.3718 - val_loss: 1.0936 - val_accuracy: 0.4744
# Epoch 17/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0909 - accuracy: 0.3829 - val_loss: 1.0924 - val_accuracy: 0.4801
# Epoch 18/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0895 - accuracy: 0.3771 - val_loss: 1.0912 - val_accuracy: 0.4915
# Epoch 19/40
# 59/59 [==============================] - 4s 70ms/step - loss: 1.0905 - accuracy: 0.3882 - val_loss: 1.0899 - val_accuracy: 0.4915
# Epoch 20/40
# 59/59 [==============================] - 4s 71ms/step - loss: 1.0910 - accuracy: 0.3692 - val_loss: 1.0889 - val_accuracy: 0.5000
# Epoch 21/40
# 59/59 [==============================] - 4s 71ms/step - loss: 1.0882 - accuracy: 0.3893 - val_loss: 1.0877 - val_accuracy: 0.5000
# Epoch 22/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0852 - accuracy: 0.4100 - val_loss: 1.0865 - val_accuracy: 0.5114
# Epoch 23/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0874 - accuracy: 0.3919 - val_loss: 1.0853 - val_accuracy: 0.5114
# Epoch 24/40
# 59/59 [==============================] - 4s 68ms/step - loss: 1.0855 - accuracy: 0.4158 - val_loss: 1.0841 - val_accuracy: 0.5114
# Epoch 25/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0849 - accuracy: 0.4301 - val_loss: 1.0829 - val_accuracy: 0.5142
# Epoch 26/40
# 59/59 [==============================] - 4s 68ms/step - loss: 1.0845 - accuracy: 0.4121 - val_loss: 1.0817 - val_accuracy: 0.5199
# Epoch 27/40
# 59/59 [==============================] - 4s 68ms/step - loss: 1.0817 - accuracy: 0.4327 - val_loss: 1.0806 - val_accuracy: 0.5256
# Epoch 28/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0797 - accuracy: 0.4380 - val_loss: 1.0794 - val_accuracy: 0.5256
# Epoch 29/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0798 - accuracy: 0.4428 - val_loss: 1.0783 - val_accuracy: 0.5284
# Epoch 30/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0762 - accuracy: 0.4629 - val_loss: 1.0772 - val_accuracy: 0.5284
# Epoch 31/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0785 - accuracy: 0.4613 - val_loss: 1.0759 - val_accuracy: 0.5284
# Epoch 32/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0780 - accuracy: 0.4719 - val_loss: 1.0747 - val_accuracy: 0.5284
# Epoch 33/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0754 - accuracy: 0.4619 - val_loss: 1.0736 - val_accuracy: 0.5341
# Epoch 34/40
# 59/59 [==============================] - 4s 71ms/step - loss: 1.0750 - accuracy: 0.4746 - val_loss: 1.0724 - val_accuracy: 0.5341
# Epoch 35/40
# 59/59 [==============================] - 4s 71ms/step - loss: 1.0724 - accuracy: 0.4793 - val_loss: 1.0713 - val_accuracy: 0.5398
# Epoch 36/40
# 59/59 [==============================] - 4s 70ms/step - loss: 1.0706 - accuracy: 0.5026 - val_loss: 1.0701 - val_accuracy: 0.5398
# Epoch 37/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0735 - accuracy: 0.4672 - val_loss: 1.0690 - val_accuracy: 0.5483
# Epoch 38/40
# 59/59 [==============================] - 4s 68ms/step - loss: 1.0692 - accuracy: 0.5138 - val_loss: 1.0679 - val_accuracy: 0.5511
# Epoch 39/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0684 - accuracy: 0.5026 - val_loss: 1.0668 - val_accuracy: 0.5511
# Epoch 40/40
# 59/59 [==============================] - 4s 69ms/step - loss: 1.0687 - accuracy: 0.5180 - val_loss: 1.0655 - val_accuracy: 0.5568
# 8/8 [==============================] - 1s 19ms/step - loss: 1.0614 - accuracy: 0.5873
# 테스트 정확도 : 58.730%

# %% [markdown]
# #### 2. epochs 영향 (이미 lr = 0.1일 때 test accuracy가 1.0이므로 비교할 필요가 없다고 판단)

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 40
lr = 0.1

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/rsp_Xception_change_hyperparameters.keras"

base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False
 
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate= lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
start = time.time()
model.predict(test_set)
end = time.time()
model3_predict_time = end - start # prediction_time

rsp_results.loc["Xception_change_hp"] = (model3_test_acc, model3_test_loss, model3_predict_time)
# Out:
# Epoch 1/40
# 59/59 [==============================] - 10s 85ms/step - loss: 0.3699 - accuracy: 0.8538 - val_loss: 1.6396 - val_accuracy: 0.6619
# Epoch 2/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.2166 - accuracy: 0.9248 - val_loss: 1.7996 - val_accuracy: 0.6222
# Epoch 3/40
# 59/59 [==============================] - 4s 70ms/step - loss: 0.1820 - accuracy: 0.9349 - val_loss: 1.1803 - val_accuracy: 0.6108
# Epoch 4/40
# 59/59 [==============================] - 4s 70ms/step - loss: 0.1661 - accuracy: 0.9386 - val_loss: 0.2874 - val_accuracy: 0.8864
# Epoch 5/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1667 - accuracy: 0.9386 - val_loss: 2.8590 - val_accuracy: 0.5795
# Epoch 6/40
# 59/59 [==============================] - 4s 63ms/step - loss: 0.1541 - accuracy: 0.9460 - val_loss: 1.2912 - val_accuracy: 0.7358
# Epoch 7/40
# 59/59 [==============================] - 5s 92ms/step - loss: 0.1625 - accuracy: 0.9407 - val_loss: 0.2604 - val_accuracy: 0.8892
# Epoch 8/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1365 - accuracy: 0.9507 - val_loss: 0.8097 - val_accuracy: 0.7585
# Epoch 9/40
# 59/59 [==============================] - 4s 70ms/step - loss: 0.1206 - accuracy: 0.9534 - val_loss: 0.0501 - val_accuracy: 0.9858
# Epoch 10/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1205 - accuracy: 0.9566 - val_loss: 2.1497 - val_accuracy: 0.5767
# Epoch 11/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1467 - accuracy: 0.9454 - val_loss: 0.2991 - val_accuracy: 0.8608
# Epoch 12/40
# 59/59 [==============================] - 4s 63ms/step - loss: 0.1170 - accuracy: 0.9592 - val_loss: 1.8714 - val_accuracy: 0.5597
# Epoch 13/40
# 59/59 [==============================] - 4s 64ms/step - loss: 0.1041 - accuracy: 0.9608 - val_loss: 1.8743 - val_accuracy: 0.5625
# Epoch 14/40
# 59/59 [==============================] - 4s 64ms/step - loss: 0.1107 - accuracy: 0.9603 - val_loss: 0.6608 - val_accuracy: 0.7869
# Epoch 15/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1421 - accuracy: 0.9470 - val_loss: 1.0171 - val_accuracy: 0.6506
# Epoch 16/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1296 - accuracy: 0.9566 - val_loss: 0.3043 - val_accuracy: 0.8977
# Epoch 17/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1341 - accuracy: 0.9460 - val_loss: 0.3192 - val_accuracy: 0.8693
# Epoch 18/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1008 - accuracy: 0.9672 - val_loss: 3.5997 - val_accuracy: 0.4460
# Epoch 19/40
# 59/59 [==============================] - 4s 62ms/step - loss: 0.1120 - accuracy: 0.9571 - val_loss: 0.6091 - val_accuracy: 0.7983
# 8/8 [==============================] - 1s 19ms/step - loss: 0.0333 - accuracy: 0.9921
# 테스트 정확도 : 99.206%
# 8/8 [==============================] - 1s 15ms/step

# %% [markdown]
# ****

# %% [markdown]
# ## 각 evaluation 결과

# %%
rsp_results
# Out:
#                                     test_acc test_loss pred_time
# Xception_without_data_augmentation       1.0  0.000018  0.874107
# Xception_with_data_augmentation          1.0  0.000001  0.904584
# Xception_change_hp                  0.992063  0.033273  0.909968

# %%
models = list(rsp_results.index)
test_accs = list(rsp_results["test_acc"])
plt.bar(range(len((models))), test_accs, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Test Accuracy for Rock_paper_scissors dataset')

ax = plt.subplot()
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/rsp_test_accuracy.png')

# %%
test_losss = list(rsp_results["test_loss"])
plt.bar(range(len((models))), test_losss, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Test Loss for Rock_paper_scissors dataset')

ax = plt.subplot()
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/rsp_test_loss.png')

# %%
pred_times = list(rsp_results["pred_time"])
plt.bar(range(len((models))), pred_times, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Prediction time(s) for Rock_paper_scissors dataset')

ax = plt.subplot()
ax.set_xticks([0, 1, 2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/rsp_prediction_time.png')

# %% [markdown]
# ***

# %% [markdown]
# # 2. Citrus_leaves

# %%
dataset, info = tfds.load("citrus_leaves", as_supervised=True, with_info=True)
class_names = info.features["label"].names 
n_classes = info.features["label"].num_classes # 10
dataset_size = info.splits["train"].num_examples # 594

test_set_raw, valid_set_raw, train_set_raw = tfds.load("citrus_leaves", 
                                                       as_supervised=True, 
                                                       split=["train[:10%]","train[10%:25%]", "train[25%:]"])


def preprocess(image, label):
  resized_image = tf.image.resize(image, [224, 224])
  final_image = keras.applications.xception.preprocess_input(resized_image)
  return final_image, label


batch_size = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(preprocess).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

citrusleaves_results = pd.DataFrame(columns = ['test_acc', 'test_loss', 'pred_time'], index = ['Xception_without_data_augmentation', 'Xception_with_data_augmentation', 'Xception_change_hp'])

# %% [markdown]
# ```label names``` = ['Black spot', 'canker', 'greening', 'healthy']
# ```num_classes``` = 4
# ```
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=uint8),
#     'image/filename': Text(shape=(), dtype=string),
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=4),
# })
# ```
# ```
# info.splits
# >>> {Split('train'): <SplitInfo num_examples=594, num_shards=1>}
# ```

# %%
plt.figure(figsize=(10, 10))
index = 0
for image, label in train_set_raw.take(9):
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title("Class: {}".format(class_names[label]))
    plt.axis("off")

plt.show()

# %% [markdown]
# ## (1) Data augmentation 미적용

# %%
base_model= keras.applications.xception.Xception(weights="imagenet", include_top=False)
avg = keras.layers.GlobalAveragePooling2D()(base_model.output)
output = keras.layers.Dense(n_classes, activation="softmax")(avg)
model = keras.models.Model(inputs=base_model.input, outputs=output)

# fine-tuning
for layer in base_model.layers:
   layer.trainable = True

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/citrusleaves_Xception_without_data_augmentation.keras"
EPOCHS = 40 

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb,
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

model1_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model1_history, "citrusleaves_without_data_augmentation") # history graph
model1_test_loss, model1_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과

start = time.time()
model.predict(test_set)
end = time.time()
model1_predict_time = end - start # prediction_time

citrusleaves_results.loc["Xception_without_data_augmentation"] = (model1_test_acc, model1_test_loss, model1_predict_time)
# Out:
# Epoch 1/40
# 13/13 [==============================] - 30s 671ms/step - loss: 1.0914 - accuracy: 0.5553 - val_loss: 0.9509 - val_accuracy: 0.6250
# Epoch 2/40
# 13/13 [==============================] - 7s 519ms/step - loss: 0.3856 - accuracy: 0.9279 - val_loss: 0.8320 - val_accuracy: 0.6875
# Epoch 3/40
# 13/13 [==============================] - 6s 457ms/step - loss: 0.1480 - accuracy: 0.9712 - val_loss: 0.8847 - val_accuracy: 0.6719
# Epoch 4/40
# 13/13 [==============================] - 6s 462ms/step - loss: 0.0460 - accuracy: 0.9928 - val_loss: 0.8896 - val_accuracy: 0.7188
# Epoch 5/40
# 13/13 [==============================] - 6s 466ms/step - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.9405 - val_accuracy: 0.7031
# Epoch 6/40
# 13/13 [==============================] - 6s 468ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.9394 - val_accuracy: 0.7188
# Epoch 7/40
# 13/13 [==============================] - 6s 475ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9410 - val_accuracy: 0.7188
# Epoch 8/40
# 13/13 [==============================] - 6s 478ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.9225 - val_accuracy: 0.7812
# Epoch 9/40
# 13/13 [==============================] - 6s 482ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.9158 - val_accuracy: 0.7812
# Epoch 10/40
# 13/13 [==============================] - 6s 486ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.9183 - val_accuracy: 0.7969
# Epoch 11/40
# 13/13 [==============================] - 6s 492ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.9070 - val_accuracy: 0.7969
# Epoch 12/40
# 13/13 [==============================] - 6s 502ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9024 - val_accuracy: 0.7969
# 2/2 [==============================] - 3s 2s/step - loss: 0.6950 - accuracy: 0.7288
# 테스트 정확도 : 72.881%
# 2/2 [==============================] - 1s 114ms/step

# %% [markdown]
# ## (2) Data augmentation 적용

# %%
def central_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]])
    top_crop = (shape[0] - min_dim) // 4
    bottom_crop = shape[0] - top_crop
    left_crop = (shape[1] - min_dim) // 4
    right_crop = shape[1] - left_crop
    return image[top_crop:bottom_crop, left_crop:right_crop]

def random_crop(image):
    shape = tf.shape(image)
    min_dim = tf.reduce_min([shape[0], shape[1]]) * 90 // 100
    return tf.image.random_crop(image, [min_dim, min_dim, 3])


def preprocess(image, label, randomize=False):
    if randomize:
        cropped_image = random_crop(image)
        cropped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        cropped_image = central_crop(image)
    resized_image = tf.image.resize(cropped_image, [224, 224])
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label


# 데이터 증강을 포함한 전처리 함수 정의
def augment_preprocess(image, label):
    augmented_image = data_augmentation(image)
    resized_image = tf.image.resize(augmented_image, [224, 224])
    normalized_image = resized_image / 255.0
    return normalized_image, label

data_augmentation = keras.Sequential( # data augmentation
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# - **augmentation 결과 확인**

# %%
# augmentation 결과 확인 
batch_size = 32
train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(augment_preprocess)).batch(batch_size).prefetch(1)
train_set = train_set_raw.map(augment_preprocess)

plt.figure(figsize = (10, 10))
index = 0
for image, label in train_set.take(9):
    index += 1
    plt.subplot(3, 3, index)
    plt.imshow(image)
    plt.title("Class: {}".format(class_names[label]))

plt.show()

# %%
# 모델 적용을 위해 Input_size 수정한 ver
def preprocess(image, label, randomize=False):
    if randomize:
        cropped_image = random_crop(image)
        cropped_image = tf.image.random_flip_left_right(cropped_image)
    else:
        cropped_image = central_crop(image)
    resized_image = tf.image.resize(cropped_image, [224, 224])
    resized_image = tf.squeeze(resized_image)  # 차원 축소
    final_image = keras.applications.xception.preprocess_input(resized_image)
    return final_image, label

# 데이터 증강을 포함한 전처리 함수 정의 (모델 적용을 위해 Input_size 수정한 ver)
def augment_preprocess(image, label):
    augmented_image = data_augmentation(image)
    resized_image = tf.image.resize(augmented_image, [224, 224])
    normalized_image = resized_image / 255.0
    return normalized_image, label

data_augmentation = keras.Sequential(
    [
        layers.Conv2D(3, 3, input_shape=(224, 224, 3)),  # 입력 형태 설정
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

train_set = train_set_raw.shuffle(1000).repeat()
train_set = train_set.map(partial(preprocess, randomize=True)).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(preprocess).batch(batch_size).prefetch(1)
test_set = test_set_raw.map(preprocess).batch(batch_size).prefetch(1)

base_model= keras.applications.xception.Xception(weights="imagenet", include_top=False)
# fine-tuning
for layer in base_model.layers:
   layer.trainable = True

# inputs = keras.Input(shape=(None, None, 3)) 
inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/citrusleaves_Xception_with_data_augmentation.keras"
EPOCHS = 40

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    early_stopping_cb, # Early_Stopping
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model2_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model2_history, "citrusleaves_with_data_augmentation") # history graph
model2_test_loss, model2_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과

start = time.time()
model.predict(test_set)
end = time.time()
model2_predict_time = end - start # prediction_time

citrusleaves_results.loc["Xception_with_data_augmentation"] = (model2_test_acc, model2_test_loss, model2_predict_time)
# Out:
# Epoch 1/40
# 13/13 [==============================] - 28s 631ms/step - loss: 1.3370 - accuracy: 0.3534 - val_loss: 1.3762 - val_accuracy: 0.3125
# Epoch 2/40
# 13/13 [==============================] - 7s 512ms/step - loss: 0.8957 - accuracy: 0.6538 - val_loss: 1.5535 - val_accuracy: 0.3438
# Epoch 3/40
# 13/13 [==============================] - 7s 522ms/step - loss: 0.6084 - accuracy: 0.7356 - val_loss: 2.0907 - val_accuracy: 0.3594
# Epoch 4/40
# 13/13 [==============================] - 7s 521ms/step - loss: 0.4502 - accuracy: 0.8245 - val_loss: 2.2973 - val_accuracy: 0.3125
# Epoch 5/40
# 13/13 [==============================] - 7s 510ms/step - loss: 0.3194 - accuracy: 0.8822 - val_loss: 2.0736 - val_accuracy: 0.2812
# Epoch 6/40
# 13/13 [==============================] - 6s 501ms/step - loss: 0.2021 - accuracy: 0.9231 - val_loss: 2.4829 - val_accuracy: 0.2969
# Epoch 7/40
# 13/13 [==============================] - 6s 496ms/step - loss: 0.1869 - accuracy: 0.9279 - val_loss: 2.2981 - val_accuracy: 0.3125
# Epoch 8/40
# 13/13 [==============================] - 6s 490ms/step - loss: 0.1316 - accuracy: 0.9543 - val_loss: 2.3407 - val_accuracy: 0.3750
# Epoch 9/40
# 13/13 [==============================] - 6s 490ms/step - loss: 0.1107 - accuracy: 0.9591 - val_loss: 2.5557 - val_accuracy: 0.3125
# Epoch 10/40
# 13/13 [==============================] - 6s 491ms/step - loss: 0.0980 - accuracy: 0.9688 - val_loss: 2.1233 - val_accuracy: 0.4219
# Epoch 11/40
# 13/13 [==============================] - 6s 495ms/step - loss: 0.0773 - accuracy: 0.9688 - val_loss: 2.2019 - val_accuracy: 0.3594
# 2/2 [==============================] - 2s 1s/step - loss: 1.5011 - accuracy: 0.3051
# 테스트 정확도 : 30.508%
# 2/2 [==============================] - 1s 111ms/step

# %% [markdown]
# ## (3) 1-(2)에서 hyper parameter 변형
# - 기존
#   - epochs = 40
#   - learning_rate = 0.01
#   - batch_size = 32

# %% [markdown]
# #### 1. learning rate의 영향

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 40
lr = 0.1

# 마지막에서 네번째 층까지 모든 층 동결하기 
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

callbacks = [
    early_stopping_cb,
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/40
# 13/13 [==============================] - 10s 456ms/step - loss: 2.1236 - accuracy: 0.4255 - val_loss: 26.1368 - val_accuracy: 0.4219
# Epoch 2/40
# 13/13 [==============================] - 5s 396ms/step - loss: 1.3488 - accuracy: 0.5577 - val_loss: 2.0619 - val_accuracy: 0.5938
# Epoch 3/40
# 13/13 [==============================] - 5s 403ms/step - loss: 0.7556 - accuracy: 0.6875 - val_loss: 1.5935 - val_accuracy: 0.7344
# Epoch 4/40
# 13/13 [==============================] - 5s 376ms/step - loss: 0.5291 - accuracy: 0.8149 - val_loss: 2.2730 - val_accuracy: 0.7031
# 13/13 [==============================] - 5s 371ms/step - loss: 0.1403 - accuracy: 0.9543 - val_loss: 1.0971 - val_accuracy: 0.8281
# Epoch 25/40
# 13/13 [==============================] - 5s 370ms/step - loss: 0.1298 - accuracy: 0.9639 - val_loss: 0.9455 - val_accuracy: 0.8594
# Epoch 26/40
# 13/13 [==============================] - 5s 370ms/step - loss: 0.1301 - accuracy: 0.9495 - val_loss: 1.5122 - val_accuracy: 0.8281
# Epoch 27/40
# 13/13 [==============================] - 5s 369ms/step - loss: 0.1281 - accuracy: 0.9615 - val_loss: 1.1904 - val_accuracy: 0.8125
# Epoch 28/40
# 13/13 [==============================] - 5s 369ms/step - loss: 0.1380 - accuracy: 0.9591 - val_loss: 1.1054 - val_accuracy: 0.8750
# Epoch 29/40
# 13/13 [==============================] - 5s 369ms/step - loss: 0.1043 - accuracy: 0.9567 - val_loss: 0.8804 - val_accuracy: 0.8438
# Epoch 30/40
# 13/13 [==============================] - 5s 368ms/step - loss: 0.1316 - accuracy: 0.9639 - val_loss: 0.8589 - val_accuracy: 0.8594
# Epoch 31/40
# 13/13 [==============================] - 5s 368ms/step - loss: 0.1833 - accuracy: 0.9471 - val_loss: 0.9764 - val_accuracy: 0.8281
# 2/2 [==============================] - 1s 134ms/step - loss: 0.5730 - accuracy: 0.8475
# 테스트 정확도 : 84.746%

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 40
lr = 1e-5

# 마지막에서 네번째 층까지 모든 층 동결하기 
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

callbacks = [
    early_stopping_cb,
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/40
# 13/13 [==============================] - 10s 458ms/step - loss: 1.4234 - accuracy: 0.2212 - val_loss: 1.4349 - val_accuracy: 0.1719
# Epoch 2/40
# 13/13 [==============================] - 5s 394ms/step - loss: 1.4139 - accuracy: 0.2260 - val_loss: 1.4301 - val_accuracy: 0.1719
# Epoch 3/40
# 13/13 [==============================] - 5s 400ms/step - loss: 1.4086 - accuracy: 0.2139 - val_loss: 1.4247 - val_accuracy: 0.1719
# Epoch 23/40
# 13/13 [==============================] - 5s 400ms/step - loss: 1.3280 - accuracy: 0.3534 - val_loss: 1.3463 - val_accuracy: 0.3281
# Epoch 24/40
# 13/13 [==============================] - 5s 400ms/step - loss: 1.3316 - accuracy: 0.3702 - val_loss: 1.3425 - val_accuracy: 0.3438
# Epoch 25/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.3276 - accuracy: 0.3774 - val_loss: 1.3391 - val_accuracy: 0.3438
# Epoch 26/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.3289 - accuracy: 0.3606 - val_loss: 1.3361 - val_accuracy: 0.3594
# Epoch 27/40
# 13/13 [==============================] - 5s 398ms/step - loss: 1.3208 - accuracy: 0.3822 - val_loss: 1.3329 - val_accuracy: 0.3594
# Epoch 28/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.3102 - accuracy: 0.3870 - val_loss: 1.3292 - val_accuracy: 0.3750
# Epoch 29/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.3184 - accuracy: 0.3822 - val_loss: 1.3263 - val_accuracy: 0.3750
# Epoch 30/40
# 13/13 [==============================] - 5s 398ms/step - loss: 1.3105 - accuracy: 0.3750 - val_loss: 1.3227 - val_accuracy: 0.3750
# Epoch 31/40
# 13/13 [==============================] - 5s 397ms/step - loss: 1.3047 - accuracy: 0.3918 - val_loss: 1.3195 - val_accuracy: 0.3750
# Epoch 32/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.3145 - accuracy: 0.3870 - val_loss: 1.3159 - val_accuracy: 0.3750
# Epoch 33/40
# 13/13 [==============================] - 5s 398ms/step - loss: 1.3073 - accuracy: 0.3918 - val_loss: 1.3131 - val_accuracy: 0.3750
# Epoch 34/40
# 13/13 [==============================] - 5s 397ms/step - loss: 1.3043 - accuracy: 0.3702 - val_loss: 1.3095 - val_accuracy: 0.3750
# Epoch 35/40
# 13/13 [==============================] - 5s 399ms/step - loss: 1.2919 - accuracy: 0.4062 - val_loss: 1.3067 - val_accuracy: 0.3750
# Epoch 36/40
# 13/13 [==============================] - 6s 435ms/step - loss: 1.2835 - accuracy: 0.4014 - val_loss: 1.3039 - val_accuracy: 0.3750
# Epoch 37/40
# 13/13 [==============================] - 5s 397ms/step - loss: 1.2876 - accuracy: 0.4231 - val_loss: 1.3002 - val_accuracy: 0.4062
# Epoch 38/40
# 13/13 [==============================] - 5s 403ms/step - loss: 1.2790 - accuracy: 0.4231 - val_loss: 1.2974 - val_accuracy: 0.4062
# Epoch 39/40
# 13/13 [==============================] - 5s 402ms/step - loss: 1.2837 - accuracy: 0.4231 - val_loss: 1.2940 - val_accuracy: 0.4062
# Epoch 40/40
# 13/13 [==============================] - 5s 403ms/step - loss: 1.2799 - accuracy: 0.4207 - val_loss: 1.2915 - val_accuracy: 0.4219
# 2/2 [==============================] - 1s 115ms/step - loss: 1.2280 - accuracy: 0.5424
# 테스트 정확도 : 54.237%

# %% [markdown]
# #### 2. epochs의 영향

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 150
lr = 0.1

# 마지막에서 네번째 층까지 모든 층 동결하기 
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

callbacks = [
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/150
# 13/13 [==============================] - 10s 461ms/step - loss: 0.4259 - accuracy: 0.8510 - val_loss: 0.8209 - val_accuracy: 0.8281
# Epoch 2/150
# 13/13 [==============================] - 5s 392ms/step - loss: 0.1673 - accuracy: 0.9423 - val_loss: 0.7611 - val_accuracy: 0.7812
# Epoch 3/150
# 13/13 [==============================] - 5s 365ms/step - loss: 0.0865 - accuracy: 0.9784 - val_loss: 0.8291 - val_accuracy: 0.8438
# Epoch 4/150
# 13/13 [==============================] - 5s 397ms/step - loss: 0.1173 - accuracy: 0.9567 - val_loss: 0.7453 - val_accuracy: 0.8750
# Epoch 5/150
# 13/13 [==============================] - 5s 372ms/step - loss: 0.0905 - accuracy: 0.9688 - val_loss: 1.2405 - val_accuracy: 0.8281
# Epoch 6/150
# 13/13 [==============================] - 5s 375ms/step - loss: 0.1336 - accuracy: 0.9423 - val_loss: 1.1783 - val_accuracy: 0.7812
# Epoch 7/150
# 13/13 [==============================] - 5s 378ms/step - loss: 0.1616 - accuracy: 0.9519 - val_loss: 0.8713 - val_accuracy: 0.8438
# Epoch 8/150
# 13/13 [==============================] - 5s 381ms/step - loss: 0.1172 - accuracy: 0.9591 - val_loss: 1.0010 - val_accuracy: 0.8125
# Epoch 9/150
# 13/13 [==============================] - 5s 409ms/step - loss: 0.1429 - accuracy: 0.9471 - val_loss: 0.7354 - val_accuracy: 0.8750
# Epoch 10/150
# 13/13 [==============================] - 5s 376ms/step - loss: 0.0776 - accuracy: 0.9688 - val_loss: 1.0287 - val_accuracy: 0.7969
# Epoch 11/150
# 13/13 [==============================] - 5s 373ms/step - loss: 0.1367 - accuracy: 0.9543 - val_loss: 0.8321 - val_accuracy: 0.8281
# Epoch 12/150
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0723 - accuracy: 0.9688 - val_loss: 1.2391 - val_accuracy: 0.8438
# Epoch 13/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0
150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 1.5746 - val_accuracy: 0.8125
# Epoch 132/150
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0742 - accuracy: 0.9808 - val_loss: 1.3683 - val_accuracy: 0.8594
# Epoch 133/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0432 - accuracy: 0.9880 - val_loss: 1.2611 - val_accuracy: 0.7969
# Epoch 134/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0273 - accuracy: 0.9904 - val_loss: 0.9716 - val_accuracy: 0.8281
# Epoch 135/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0255 - accuracy: 0.9904 - val_loss: 0.9481 - val_accuracy: 0.8438
# Epoch 136/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0251 - accuracy: 0.9928 - val_loss: 1.0891 - val_accuracy: 0.8750
# Epoch 137/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0236 - accuracy: 0.9952 - val_loss: 1.2746 - val_accuracy: 0.8281
# Epoch 138/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0213 - accuracy: 0.9880 - val_loss: 1.1337 - val_accuracy: 0.8281
# Epoch 139/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0176 - accuracy: 0.9928 - val_loss: 0.9654 - val_accuracy: 0.8438
# Epoch 140/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.9661 - val_accuracy: 0.8438
# Epoch 141/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0186 - accuracy: 0.9904 - val_loss: 1.2973 - val_accuracy: 0.8594
# Epoch 142/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0408 - accuracy: 0.9928 - val_loss: 1.1796 - val_accuracy: 0.7969
# Epoch 143/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0131 - accuracy: 0.9928 - val_loss: 1.2724 - val_accuracy: 0.8594
# Epoch 144/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0099 - accuracy: 0.9976 - val_loss: 1.4003 - val_accuracy: 0.8125
# Epoch 145/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 1.5621 - val_accuracy: 0.7812
# Epoch 146/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 1.3342 - val_accuracy: 0.8281
# Epoch 147/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0065 - accuracy: 0.9952 - val_loss: 1.3517 - val_accuracy: 0.8281
# Epoch 148/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0104 - accuracy: 0.9952 - val_loss: 1.3508 - val_accuracy: 0.8438
# Epoch 149/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0131 - accuracy: 0.9976 - val_loss: 1.3355 - val_accuracy: 0.8281
# Epoch 150/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0396 - accuracy: 0.9952 - val_loss: 1.5451 - val_accuracy: 0.8125
# 2/2 [==============================] - 1s 132ms/step - loss: 0.7210 - accuracy: 0.8475
# 테스트 정확도 : 84.746%

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 150
lr = 0.1

# 마지막에서 네번째 층까지 모든 층 동결하기 
base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False

inputs = keras.Input(shape=(224, 224, 3))

x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate=lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

MODEL_SAVE_PATH = "Xception_change_hyperparameters.keras"

early_stopping_cb=keras.callbacks.EarlyStopping(patience = 40) # Early_Stopping
callbacks = [
    early_stopping_cb,
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
# Out:
# Epoch 1/150
# 13/13 [==============================] - 11s 513ms/step - loss: 0.4385 - accuracy: 0.8702 - val_loss: 0.7891 - val_accuracy: 0.8125
# Epoch 2/150
# 13/13 [==============================] - 5s 366ms/step - loss: 0.0594 - accuracy: 0.9832 - val_loss: 0.9463 - val_accuracy: 0.8438
# Epoch 3/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0285 - accuracy: 0.9904 - val_loss: 1.0166 - val_accuracy: 0.8438
# Epoch 4/150
# 13/13 [==============================] - 5s 373ms/step - loss: 0.0328 - accuracy: 0.9856 - val_loss: 1.1286 - val_accuracy: 0.8438
# Epoch 5/150
# 13/13 [==============================] - 5s 376ms/step - loss: 0.0193 - accuracy: 0.9904 - val_loss: 1.1969 - val_accuracy: 0.8125
# Epoch 6/150
# 13/13 [==============================] - 5s 379ms/step - loss: 0.0268 - accuracy: 0.9976 - val_loss: 1.1634 - val_accuracy: 0.8125
# Epoch 7/150
# 13/13 [==============================] - 5s 379ms/step - loss: 0.0345 - accuracy: 0.9856 - val_loss: 1.1527 - val_accuracy: 0.8281
# Epoch 8/150
# 13/13 [==============================] - 5s 375ms/step - loss: 0.0176 - accuracy: 0.9952 - val_loss: 0.9760 - val_accuracy: 0.8438
# Epoch 9/150
# 13/13 [==============================] - 5s 375ms/step - loss: 0.0126 - accuracy: 0.9952 - val_loss: 1.1982 - val_accuracy: 0.8125
# Epoch 10/150
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0345 - accuracy: 0.9904 - val_loss: 1.0975 - val_accuracy: 0.8125
# Epoch 11/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0120 - accuracy: 0.9952 - val_loss: 1.3711 - val_accuracy: 0.7969
# Epoch 12/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 1.2528 - val_accuracy: 0.7812
# Epoch 13/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0266 - accuracy: 0.9856 - val_loss: 1.3244 - val_accuracy: 0.7812
# Epoch 14/150
# 13/13 [==============================] - 5s 366ms/step - loss: 0.0254 - accuracy: 0.9856 - val_loss: 1.1128 - val_accuracy: 0.8125
# Epoch 15/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 1.2255 - val_accuracy: 0.8281
# Epoch 16/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 1.3758 - val_accuracy: 0.8125
# Epoch 17/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0301 - accuracy: 0.9904 - val_loss: 1.2104 - val_accuracy: 0.8125
# Epoch 18/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0124 - accuracy: 0.9976 - val_loss: 1.1449 - val_accuracy: 0.8438
# Epoch 19/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0344 - accuracy: 0.9904 - val_loss: 1.0830 - val_accuracy: 0.8438
# Epoch 20/150
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0782 - accuracy: 0.9904 - val_loss: 1.2773 - val_accuracy: 0.8125
# Epoch 21/150
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0316 - accuracy: 0.9880 - val_loss: 0.9526 - val_accuracy: 0.8281
# Epoch 22/150
# 13/13 [==============================] - 5s 372ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 1.0622 - val_accuracy: 0.8438
# Epoch 23/150
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 0.9707 - val_accuracy: 0.8438
# Epoch 24/150
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0314 - accuracy: 0.9832 - val_loss: 1.1239 - val_accuracy: 0.7969
# Epoch 25/150
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0250 - accuracy: 0.9904 - val_loss: 0.9614 - val_accuracy: 0.8438
# Epoch 26/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0107 - accuracy: 0.9976 - val_loss: 0.9103 - val_accuracy: 0.8438
# Epoch 27/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.0404 - val_accuracy: 0.8281
# Epoch 28/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0159 - accuracy: 0.9952 - val_loss: 1.0055 - val_accuracy: 0.8281
# Epoch 29/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0138 - accuracy: 0.9928 - val_loss: 0.9375 - val_accuracy: 0.8594
# Epoch 30/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0131 - accuracy: 0.9976 - val_loss: 1.0237 - val_accuracy: 0.8750
# Epoch 31/150
# 13/13 [==============================] - 5s 367ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 1.0720 - val_accuracy: 0.8594
# Epoch 32/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0109 - accuracy: 0.9976 - val_loss: 1.0353 - val_accuracy: 0.8750
# Epoch 33/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0137 - accuracy: 0.9928 - val_loss: 1.1245 - val_accuracy: 0.8750
# Epoch 34/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0274 - accuracy: 0.9904 - val_loss: 1.2971 - val_accuracy: 0.8594
# Epoch 35/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 1.3124 - val_accuracy: 0.8750
# Epoch 36/150
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0308 - accuracy: 0.9856 - val_loss: 1.2184 - val_accuracy: 0.8281
# Epoch 37/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.7352 - val_accuracy: 0.8125
# Epoch 38/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 1.5978 - val_accuracy: 0.8438
# Epoch 39/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0157 - accuracy: 0.9928 - val_loss: 1.4639 - val_accuracy: 0.8438
# Epoch 40/150
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 1.3633 - val_accuracy: 0.8750
# Epoch 41/150
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0086 - accuracy: 0.9976 - val_loss: 1.3604 - val_accuracy: 0.8594
# 2/2 [==============================] - 1s 125ms/step - loss: 0.6381 - accuracy: 0.8136
# 테스트 정확도 : 81.356%

# %%
# 하이퍼 파라미터 변형 (learning_rate, EPOCHS)
EPOCHS = 100
lr = 0.1

MODEL_SAVE_PATH = "/content/drive/My Drive/딥러닝/TermProject/citrusleaves_Xception_change_hyperparameters.keras"

base_model.trainable = True
for layer in base_model.layers[:-4]:
    layer.trainable = False
 
inputs = keras.Input(shape=(224, 224, 3))
x = data_augmentation(inputs) # data augmentation 적용
x = keras.applications.xception.preprocess_input(x)
x = base_model(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(n_classes, activation="softmax")(x)  

model = keras.Model(inputs=inputs, outputs=outputs)
optimizer = keras.optimizers.SGD(learning_rate= lr, momentum=0.9, nesterov=True, weight_decay=0.001)
model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = optimizer,
              metrics=["accuracy"])

# early_stopping_cb=keras.callbacks.EarlyStopping(patience = 10) # Early_Stopping
callbacks = [
    keras.callbacks.ModelCheckpoint( # Checkpoint
        filepath = MODEL_SAVE_PATH,
        save_best_only = True,
        monitor = "val_loss"
    )
]

model3_history = model.fit(train_set, epochs=EPOCHS, 
                    validation_data=valid_set,
                    steps_per_epoch=int(0.75 * dataset_size / batch_size),
                    validation_steps=int(0.15 * dataset_size / batch_size),
                    callbacks = callbacks
                    )

show_plot(model3_history) # history graph
model3_test_loss, model3_test_acc = model_test(MODEL_SAVE_PATH, test_set) # test dataset에 대한 evaluation 결과
start = time.time()
model.predict(test_set)
end = time.time()
model3_predict_time = end - start # prediction_time

citrusleaves_results.loc["Xception_change_hp"] = (model3_test_acc, model3_test_loss, model3_predict_time)
# Out:
# Epoch 1/100
# 13/13 [==============================] -
100
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.8717 - val_accuracy: 0.8594
# Epoch 89/100
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0083 - accuracy: 0.9976 - val_loss: 0.9542 - val_accuracy: 0.8594
# Epoch 90/100
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0189 - accuracy: 0.9928 - val_loss: 1.0524 - val_accuracy: 0.7969
# Epoch 91/100
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0055 - accuracy: 0.9976 - val_loss: 0.8317 - val_accuracy: 0.8594
# Epoch 92/100
# 13/13 [==============================] - 5s 371ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.8346 - val_accuracy: 0.8750
# Epoch 93/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0142 - accuracy: 0.9928 - val_loss: 0.8375 - val_accuracy: 0.8750
# Epoch 94/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.9103 - val_accuracy: 0.8594
# Epoch 95/100
# 13/13 [==============================] - 5s 370ms/step - loss: 0.0348 - accuracy: 0.9904 - val_loss: 1.1858 - val_accuracy: 0.8438
# Epoch 96/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0488 - accuracy: 0.9928 - val_loss: 0.9336 - val_accuracy: 0.8750
# Epoch 97/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0322 - accuracy: 0.9952 - val_loss: 0.9070 - val_accuracy: 0.8438
# Epoch 98/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 1.0301 - val_accuracy: 0.8438
# Epoch 99/100
# 13/13 [==============================] - 5s 368ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 1.2132 - val_accuracy: 0.8438
# Epoch 100/100
# 13/13 [==============================] - 5s 369ms/step - loss: 0.0155 - accuracy: 0.9976 - val_loss: 1.2727 - val_accuracy: 0.8438
# 2/2 [==============================] - 1s 130ms/step - loss: 0.6913 - accuracy: 0.8475
# 테스트 정확도 : 84.746%
# 2/2 [==============================] - 1s 114ms/step

# %% [markdown]
# ***

# %% [markdown]
# ## 각 evaluation 결과 확인

# %%
citrusleaves_results
# Out:
#                                     test_acc test_loss pred_time
# Xception_without_data_augmentation  0.728814  0.695039  0.965492
# Xception_with_data_augmentation     0.305085  1.501131  0.950491
# Xception_change_hp                  0.847458  0.691276   0.92538

# %%
models = list(citrusleaves_results.index)
test_accs = list(citrusleaves_results["test_acc"])
plt.bar(range(len((models))), test_accs, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Test Accuracy for citrusleaves dataset')

ax = plt.subplot()
ax.set_xticks([0,1,2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/citrusleaves_test_accuracy.png')

# %%
test_losss = list(citrusleaves_results["test_loss"])
plt.bar(range(len((models))), test_losss, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Test Loss for citrusleaves dataset')

ax = plt.subplot()
ax.set_xticks([0,1,2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/citrusleaves_test_loss.png')

# %%
pred_times = list(citrusleaves_results["pred_time"])
plt.bar(range(len((models))), pred_times, width = 0.3)

plt.xlim(-0.5, 2.5)
plt.title('Prediction time(s) for citrusleaves dataset')

ax = plt.subplot()
ax.set_xticks([0,1,2])
ax.set_xticklabels(models, fontsize = 10, rotation = 10)

plt.savefig(f'/content/drive/My Drive/딥러닝/TermProject/citrusleaves_prediction_time.png')
